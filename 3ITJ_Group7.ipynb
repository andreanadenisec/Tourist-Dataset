# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
dfPlaces = pd.read_csv('destinations.csv')
dfPlaces
# Out:
#     City/State/Island/Region    Country      Continent  \
# 0                      Dakar    Senegal         Africa
# 1           Giza Governorate      Egypt         Africa
# 2                  Marrakesh    Morocco         Africa
# 3                       Giza      Egypt         Africa
# 4                  Marrakesh    Morocco         Africa
# ..                       ...        ...            ...
# 145                  Bolivar  Venezuela  South America
# 146               Santa Cruz  Argentina  South America
# 147                 Atiplano    Bolivia  South America
# 148                Los Lagos      Chile  South America
# 149          General Carrera      Chile  South America
#
#               Tourist Destination                       Activities
# 0    African Renaissance Monument                Historical sights
# 1                Pyramids of Giza              Man-made attraction
# 2                Koutoubia Mosque              Man-made attraction
# ...

# %%
dfPlaces.head(5)
# Out:
#   City/State/Island/Region  Country Continent           Tourist Destination  \
# 0                    Dakar  Senegal    Africa  African Renaissance Monument
# 1         Giza Governorate    Egypt    Africa              Pyramids of Giza
# 2                Marrakesh  Morocco    Africa              Koutoubia Mosque
# 3                     Giza    Egypt    Africa          Great Sphinx of Giza
# 4                Marrakesh  Morocco    Africa                 Djemaa El Fna
#
#                         Activities
# 0                Historical sights
# 1              Man-made attraction
# 2              Man-made attraction
# 3              Man-made attraction
# 4  Marketplace & dining experience

# %%
dfPlaces.tail(5)
# Out:
#     City/State/Island/Region    Country      Continent    Tourist Destination  \
# 145                  Bolivar  Venezuela  South America            Angel Falls
# 146               Santa Cruz  Argentina  South America  Perito Moreno Glacier
# 147                 Atiplano    Bolivia  South America           Laguna Verde
# 148                Los Lagos      Chile  South America           Pumalin Park
# 149          General Carrera      Chile  South America     Catedral de Marmol
#
#                        Activities
# 145  Natural landscapes & gardens
# 146  Natural landscapes & gardens
# 147  Natural landscapes & gardens
# 148  Natural landscapes & gardens
# 149  Natural landscapes & gardens

# %%
activities = dfPlaces.groupby(['Activities']).size()
activitiesDict = activities.to_dict()
activitiesDict = {key: value for key, value in sorted(activitiesDict.items(), key=lambda item: item[1], reverse=True,)}

activitiesName = list(activitiesDict.keys())
activitiesNum = list(activitiesDict.values())
colors = ['hotpink', 'blueviolet', 'dodgerblue','olivedrab', 'gold', 'darkorange', 'chocolate', 'maroon', 'rosybrown', 'lightgray']

# %%
plt.pie(activitiesNum, autopct='%.1f%%', pctdistance=1.14, radius=1.15, colors=colors)
plt.title('Popular Types Of Tourist Destinations Around The World',fontsize=18, loc='center', y=1.08)
plt.legend(labels=activitiesName, loc='upper center', bbox_to_anchor=(0.5, -0.04), ncol=4)
plt.show()

# %%
dfAF = dfPlaces[dfPlaces['Continent']=='Africa']
dfAS = dfPlaces[dfPlaces['Continent']=='Asia']
dfEU = dfPlaces[dfPlaces['Continent']=='Europe']
dfNA = dfPlaces[dfPlaces['Continent']=='North America']
dfOC = dfPlaces[dfPlaces['Continent']=='Oceania']
dfSA = dfPlaces[dfPlaces['Continent']=='South America']

activitiesAF = dfAF.groupby(['Activities']).size()
activitiesAS = dfAS.groupby(['Activities']).size()
activitiesEU = dfEU.groupby(['Activities']).size()
activitiesNA = dfNA.groupby(['Activities']).size()
activitiesOC = dfOC.groupby(['Activities']).size()
activitiesSA = dfSA.groupby(['Activities']).size()

activitiesDictAF = activitiesAF.to_dict()
activitiesDictAS = activitiesAS.to_dict()
activitiesDictEU = activitiesEU.to_dict()
activitiesDictNA = activitiesNA.to_dict()
activitiesDictOC = activitiesOC.to_dict()
activitiesDictSA = activitiesSA.to_dict()

activitiesDictAF = {key: value for key, value in sorted(activitiesDictAF.items(), key=lambda item: item[1], reverse=True,)}
activitiesDictAS = {key: value for key, value in sorted(activitiesDictAS.items(), key=lambda item: item[1], reverse=True,)}
activitiesDictEU = {key: value for key, value in sorted(activitiesDictEU.items(), key=lambda item: item[1], reverse=True,)}
activitiesDictNA = {key: value for key, value in sorted(activitiesDictNA.items(), key=lambda item: item[1], reverse=True,)}
activitiesDictOC = {key: value for key, value in sorted(activitiesDictOC.items(), key=lambda item: item[1], reverse=True,)}
activitiesDictSA = {key: value for key, value in sorted(activitiesDictSA.items(), key=lambda item: item[1], reverse=True,)}

activitiesNameAF = list(activitiesDictAF.keys())
activitiesNameAS = list(activitiesDictAS.keys())
activitiesNameEU = list(activitiesDictEU.keys())
activitiesNameNA = list(activitiesDictNA.keys())
activitiesNameOC = list(activitiesDictOC.keys())
activitiesNameSA = list(activitiesDictSA.keys())

activitiesNumAF = list(activitiesDictAF.values())
activitiesNumAS = list(activitiesDictAS.values())
activitiesNumEU = list(activitiesDictEU.values())
activitiesNumNA = list(activitiesDictNA.values())
activitiesNumOC = list(activitiesDictOC.values())
activitiesNumSA = list(activitiesDictSA.values())

# %%
fig, ax = plt.subplots(2, 3)

ax[0, 1].pie(activitiesNumAF, autopct='%.1f%%', pctdistance=1.25, textprops={'fontsize': 8}, colors=colors)
ax[0, 0].pie(activitiesNumAS, autopct='%.1f%%', pctdistance=1.25, textprops={'fontsize': 8}, colors=colors)
ax[0, 2].pie(activitiesNumEU, autopct='%.1f%%', pctdistance=1.25, textprops={'fontsize': 8}, colors=colors)
ax[1, 0].pie(activitiesNumNA, autopct='%.1f%%', pctdistance=1.25, textprops={'fontsize': 8}, colors=colors)
ax[1, 1].pie(activitiesNumOC, autopct='%.1f%%', pctdistance=1.25, textprops={'fontsize': 8}, colors=colors)
ax[1, 2].pie(activitiesNumSA, autopct='%.1f%%', pctdistance=1.25, textprops={'fontsize': 8}, colors=colors)

ax[0, 1].set_title('Africa', y=1.08)
ax[0, 0].set_title('Asia', y=1.08)
ax[0, 2].set_title('Europe', y=1.08)
ax[1, 0].set_title('North America', y=1.08)
ax[1, 1].set_title('Oceania', y=1.08)
ax[1, 2].set_title('South America', y=1.08)

fig.tight_layout()
fig.suptitle('Popular Types Of Tourist Destinations Per Continent', fontsize=18, y=1.08)
fig.legend(labels=activitiesName, loc='upper center', bbox_to_anchor=(0.5, -0.04), ncol=4)

plt.show()

# %%
df = pd.DataFrame([("BRUNEI", 540, 353, 109, 0, 1, 4, 5, 0, 12, 12, 1, 0, 1037), 
                   ("CAMBODIA", 421, 390, 119, 3, 0, 0, 0, 1, 3, 1, 2, 2, 942), 
                   ("INDONESIA", 5987, 4631, 2669, 8, 0, 3, 16, 50, 61, 64, 120, 125, 13734), 
                   ("LAOS", 88, 85, 17, 1, 0, 1, 3, 1, 0, 0, 2, 5, 203), 
                   ("MALAYSIA", 10385, 8860, 3593, 11, 3, 1, 26, 66, 56, 90, 170, 98, 23359), 
                   ("MYANMAR", 1327, 889, 563, 2, 1, 0, 1, 10, 10, 11, 34, 29, 2877), 
                   ("OVERSEAS FILIPINOS", 14032, 22829, 11604, 21, 4138, 336, 2138, 12966, 3637, 1804, 4535, 6040, 84080),
                   ("TOTAL 2020", 796164, 462681, 139325, 948, 4495, 1522, 5518, 18330, 10047, 10108, 13604, 19793, 1482535),
                   ("TOTAL 2019", 723390, 766865, 714309, 662987, 621719, 643780, 719057, 702843, 606553, 638549, 684063, 776798, '-')],
    columns = ("COUNTRY OF RESIDENCE", "JAN", "FEB", "MAR", "APR", "MAY", "JUN", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC", "JAN-DEC 2020"))

# %%
df.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0907c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >COUNTRY OF RESIDENCE</th>
#       <th class="col_heading level0 col1" >JAN</th>
#       <th class="col_heading level0 col2" >FEB</th>
#       <th class="col_heading level0 col3" >MAR</th>
#       <th class="col_heading level0 col4" >APR</th>
#       <th class="col_heading level0 col5" >MAY</th>
#       <th class="col_heading level0 col6" >JUN</th>
#       <th class="col_heading level0 col7" >JUL</th>
#       <th class="col_heading level0 col8" >AUG</th>
#       <th class="col_heading level0 col9" >SEP</th>
#       <th class="col_heading level0 col10" >OCT</th>
#       <th class="col_heading level0 col11" >NOV</th>
#       <th class="col_heading level0 col12" >DEC</th>
#       <th class="col_heading level0 col13" >JAN-DEC 2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0907c_row0_col0" class="data row0 col0" >BRUNEI</td>
# ...

# %%
df.head(5)
# Out:
#   COUNTRY OF RESIDENCE    JAN   FEB   MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0               BRUNEI    540   353   109    0    1    4    5    0   12   12
# 1             CAMBODIA    421   390   119    3    0    0    0    1    3    1
# 2            INDONESIA   5987  4631  2669    8    0    3   16   50   61   64
# 3                 LAOS     88    85    17    1    0    1    3    1    0    0
# 4             MALAYSIA  10385  8860  3593   11    3    1   26   66   56   90
#
#    NOV  DEC JAN-DEC 2020
# 0    1    0         1037
# 1    2    2          942
# 2  120  125        13734
# 3    2    5          203
# 4  170   98        23359

# %%
df.tail(5)
# Out:
#                  COUNTRY OF RESIDENCE     JAN     FEB     MAR     APR     MAY  \
# 66                       SOUTH AFRICA    1106     466     260      12       5
# 67  OTHERS AND UNSPECIFIED RESIDENCES   10969    7598    3290     119      18
# 68                 OVERSEAS FILIPINOS   14032   22829   11604      21    4138
# 69                         TOTAL 2020  796164  462681  139325     948    4495
# 70                         TOTAL 2019  723390  766865  714309  662987  621719
#
#        JUN     JUL     AUG     SEP     OCT     NOV     DEC JAN-DEC 2020
# 66       2      15      63      44      65      56      65         2159
# 67      66     214     441     601     724     737     813        25590
# 68     336    2138   12966    3637    1804    4535    6040        84080
# 69    1522    5518   18330   10047   10108   13604   19793      1482535
# 70  643780  719057  702843  606553  638549  684063  776798            -

# %%
mon = df.columns[1:13]
num2020 = df.iloc[-2, 1:13]
num2019 = df.iloc[-1, 1:13]

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=40)
plt.grid(linewidth=1)
plt.title("VISITOR ARRIVALS TO THE PHILIPPINES (2020 & 2019)", fontweight='bold')
plt.xlabel("Months", fontweight='bold')
plt.ylabel("Total", fontweight='bold')
plt.yticks(np.arange(0, 750000, 40000)) 

plt.plot(mon, num2020, color="blue", marker='o')
for i, txt in enumerate(num2020):
    plt.annotate(txt, (mon[i], num2020[i]), fontweight='bold')
    
plt.plot(mon, num2019, color ="red", marker='o')
for i, txt in enumerate(num2019):
    plt.annotate(txt, (mon[i], num2019[i]))
    
plt.legend(['Year 2020', 'Year 2019'], loc=3, prop={'size': 15})
plt.show()
